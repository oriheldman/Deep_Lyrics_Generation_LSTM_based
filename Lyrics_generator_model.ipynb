# %%
import numpy as np
import pandas as pd
import os
from sklearn.model_selection import train_test_split
import random
import json
from tqdm import tqdm
from datetime import datetime

# %%
import gensim.downloader as api
from gensim.models import Word2Vec
from nltk import word_tokenize
import re

# %%
import pretty_midi
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import IPython.display

# %%
random.seed(3)
np.random.seed(3)

# %% [markdown]
# ## Load and fix CSV Files
# - strip redundant whitespaces
# - combine splitted columns in lyrics
# - drop dups

# %%
df_train = pd.read_csv('lyrics_train_set.csv', header=None)
df_test = pd.read_csv('lyrics_test_set.csv', header=None)

def fix_csv_lyrics_rows(df):
    df_concat = []
    for idx, row in df.iterrows():
        lyrics = [c for c in row[2:].tolist() if c == c]
        df_concat.append([row[0], row[1], ','.join(lyrics)])
    df = pd.DataFrame(df_concat, columns=['Artist', 'Song', 'Lyrics'])
    df['Song'] = df['Song'].apply(lambda x: x.strip())
    df['Artist'] = df['Artist'].apply(lambda x: x.strip())
    df['Lyrics'] = df['Lyrics'].apply(lambda x: x.strip())
    df = df.drop_duplicates()
    return df

df_train = fix_csv_lyrics_rows(df_train)
df_test = fix_csv_lyrics_rows(df_test)

# %% [markdown]
# ### Split train to train-validaiton

# %%
df_train, df_val = train_test_split(df_train, test_size=0.1, random_state=3)

# %% [markdown]
# ### Load W2Vec Model

# %%
print('loading w2v model')
wv = api.load('glove-wiki-gigaword-300')
# Out:
# loading w2v model

# %% [markdown]
# ### Pre-process lyrics

# %%
def preprocess_text(text):
    """
    remove special chars for reducing sparsity (less OutOfVocabulary words)
    """
    allowed_chars_regex = '[^A-Za-z0 & \']+'
    text = text.lower()
    text = re.sub(allowed_chars_regex, '', text)
    words = word_tokenize(text)
    words = [w for w in words if "'" not in w]
    return words


def add_eos_token(wv):
    """
    change & token to represent EOS token
    """
    n_words = len(wv.index2word)
    emb_dim = wv.vector_size
    empty_vectors = np.array([[0]] * n_words)
    wv.vectors = np.concatenate((wv.vectors, empty_vectors), axis=1)
    eos_emb = np.array([0] * (emb_dim + 1))
    eos_emb[-1] = 1
    wv.vectors[wv.index2word.index('&')] = eos_emb


def w2vec_lookup(wv, w, pad_vec):
    if w in wv.vocab:
        return wv.vectors[wv.vocab[w].index]
    else:
        return pad_vec


def convert_lyrics_to_embeddings(wv, lyrics, songs, artists):
    """
    conver lyrics tokens to embeddings using pretrained word2vec model.
    """
    emb_dim = wv.vector_size
    pad_vec = np.array([0] * (emb_dim + 1))
    all_lyrics_embeddings = []
    all_lyrics_tokens = []
    for song_lyrics, song_name, artist in zip(lyrics, songs, artists):
        lyrics_tokens = preprocess_text(song_lyrics)
        all_lyrics_embeddings.append(np.array([w2vec_lookup(wv, w, pad_vec) for w in lyrics_tokens]))
        all_lyrics_tokens.append(lyrics_tokens)
    return all_lyrics_embeddings, all_lyrics_tokens

# %%
print('adding EOS token')
add_eos_token(wv)
# Out:
# adding EOS token

# %% [markdown]
# ## Extract MIDI- feature vectors for songs

# %%
def extract_midi_embs_for_song(midi_data, n_sentences):
    """
    helper function - create embedding for 1 song.
    fv include global features (song based) + local features (sentence-based)
    """
    pitch_dist = midi_data.get_pitch_class_histogram().tolist()
    bpm = midi_data.estimate_tempo()
    global_vec = np.array(pitch_dist + [bpm])
    fs = (n_sentences / midi_data.get_end_time())
    chroma_vector = np.array(midi_data.get_chroma(times=np.arange(0, midi_data.get_end_time(), 1. / fs)).tolist())
    
    chroma_vector = chroma_vector.transpose()
    
    if len(chroma_vector) > n_sentences:
        chroma_vector = chroma_vector[:-1]
    
    global_vec = np.tile(global_vec, (n_sentences,1))
    return np.concatenate((global_vec, chroma_vector), axis=1)
    

def extract_midi_embs_for_df(df,  mode, reg=None):
    
    def extract_key_from_fname(fname):
        artist, song = fname.split('_-_')[0].lower().replace('_', ' '), fname.split('_-_')[1].lower().replace('_', ' ')[:-4]
        return artist, song
    
    MIDI_DIR_PATH = 'midi_files'
    filenames = os.listdir(MIDI_DIR_PATH)
    filekeys = [extract_key_from_fname(fname) for fname in filenames]
    midi_files_map = dict(zip(filekeys, filenames))
    
    all_midi_embs = {}
    regressor_data = []
    for idx, row in tqdm(df.iterrows()):
        try:
            artist = row['Artist']
            song = row['Song'] 
            filename = midi_files_map[(artist, song)]
            midi_data = pretty_midi.PrettyMIDI(MIDI_DIR_PATH + "/" + filename)

            pitch_dist = midi_data.get_pitch_class_histogram().tolist()
            
            if mode == 'test':
                n_sentences = int(reg.predict(np.expand_dims(np.array([midi_data.get_end_time(), midi_data.estimate_tempo(), *pitch_dist]),0))[0])
            else: # train mode - we have the lyrics
                n_sentences = row['Lyrics'].count('&') + 1
                regressor_data.append([n_sentences, midi_data.get_end_time(), midi_data.estimate_tempo(), *pitch_dist])

            midi_emb = extract_midi_embs_for_song(midi_data, n_sentences)
            all_midi_embs[(artist, song)] = midi_emb
        except Exception as e:
#             print(e)
            continue
    return all_midi_embs, regressor_data

# %% [markdown]
# ### Create LR Model
# Create predictor for num of sentences in song using Logistic Regression

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd
import json
from sklearn.model_selection import train_test_split

def create_x_y_for_training(regressor_data):
    """
    """
    X = []
    Y = []
    for regressor_datum in regressor_data:
        x, y = regressor_datum[1:], regressor_datum[0]
        X.append(x)
        Y.append(y)
    return np.array(X), np.array(Y)

# %%
def filter_songs_without_midi_files(df, all_midi_embs_glob_train):
    """
    remove from train songs with damaged midi files (or without any)
    """
    artist = df['Artist'].tolist()
    song = df['Song'].tolist()
    df['key'] = list(zip(artist, song))
    df_filtered = df[df['key'].isin(list(all_midi_embs_glob_train.keys()))]
    return df_filtered

# %% [markdown]
# ### Run Embeddings creation flow (Lyrics + midi features)

# %%
midi_embs_train, regressor_data_train = extract_midi_embs_for_df(df_train, 'train')
midi_embs_val, regressor_data_val = extract_midi_embs_for_df(df_val, 'train')

X, Y = create_x_y_for_training([*regressor_data_train, *regressor_data_val])
reg = LinearRegression().fit(X, Y)

all_midi_embs_test, _ = extract_midi_embs_for_df(df_test, 'test', reg)

df_train_filtered = filter_songs_without_midi_files(df_train, midi_embs_train)
df_val_filtered = filter_songs_without_midi_files(df_val, midi_embs_val)

train_lyrics = df_train_filtered['Lyrics'].tolist()
train_songs = df_train_filtered['Song'].tolist()
train_artist = df_train_filtered['Artist'].tolist()

val_lyrics = df_val_filtered['Lyrics'].tolist()
val_songs = df_val_filtered['Song'].tolist()
val_artist = df_val_filtered['Artist'].tolist()

train_lyrics_embeddings, train_lyrics_tokens = convert_lyrics_to_embeddings(wv, train_lyrics, train_songs, train_artist)
val_lyrics_embeddings, val_lyrics_tokens = convert_lyrics_to_embeddings(wv, val_lyrics, val_songs, val_artist)
# Out:
# 1it [00:00,  3.21it/s]/home/heldman/.conda/envs/DL/lib/python3.6/site-packages/pretty_midi/pretty_midi.py:101: RuntimeWarning: Tempo, Key or Time signature change events found on non-zero tracks.  This is not a valid type 0 or type 1 MIDI file.  Tempo, Key or Time Signature may be wrong.
#   RuntimeWarning)
# 538it [02:22,  3.77it/s]
# 60it [00:15,  3.78it/s]
# 5it [00:01,  3.96it/s]

# %% [markdown]
# ### Prepeare Data for Keras model
# the next function aggregates the data for the keras model. it creates data of the form of [seq, word_label] for training and validation

# %%
train_vocab = {w:idx for idx, w in enumerate(set([w for song in [*train_lyrics_tokens, *val_lyrics_tokens] for w in song]))} # {w:idx}

# %%
w2v_dim = 301
step = 1
seq_len = 10
vocab_size = len(train_vocab)

def prepeare_embs_for_keras(lyrics_embedding_list, lyrics_tokens_list, midi_emb_list):
    """
    the function creates 2 seperate embeddings for lyrics and midi 
    """
#     random.shuffle(lyrics_embedding_list)
    pad_vecs = np.array([[0] * w2v_dim] * (seq_len-1))

    all_lyrics_embeddings_x = []
    all_midi_emb_x = []
    all_lyrics_W_midi_embeddings_x = []
    all_lyrics_labels_y = []
    
    
    for lyrics_embedding, midi_emb, lyrics_tokens in tqdm(zip(lyrics_embedding_list, midi_emb_list, lyrics_tokens_list)):
        lyrics_embeddings_x = []
        midi_emb_x = []
        lyrics_W_midi_embeddings_x = []
        lyrics_labels_y = []
        lyrics_embedding = np.concatenate((pad_vecs, lyrics_embedding), axis=0)
        
        sentence_idx = 1
        for i in range(0, len(lyrics_embedding) - seq_len, step):
            lyrics_emb = np.array(lyrics_embedding[i : i + seq_len])
            lyrics_embeddings_x.append(lyrics_emb)
            
            if lyrics_tokens[i] == '&':
                sentence_idx += 1
            
            midi_emb_tmp = np.mean(midi_emb[sentence_idx-1:sentence_idx+1], axis = 0)
            midi_emb_x.append(midi_emb_tmp)
            
            midi_emb_tmp = np.expand_dims(midi_emb_tmp, 0)
            midi_emb_tmp = np.tile(midi_emb_tmp, (seq_len,1))
            lyrics_w_midi_emb = np.concatenate((lyrics_emb, midi_emb_tmp), axis=1)
            lyrics_W_midi_embeddings_x.append(lyrics_w_midi_emb)
            
            y = np.zeros(vocab_size)
            y[train_vocab[lyrics_tokens[i + 1]]] = 1
            lyrics_labels_y.append(y)
            
        all_lyrics_embeddings_x.extend(lyrics_embeddings_x)
        all_midi_emb_x.extend(midi_emb_x)
        all_lyrics_W_midi_embeddings_x.extend(lyrics_W_midi_embeddings_x)
        all_lyrics_labels_y.extend(lyrics_labels_y)
        

    all_lyrics_embeddings_x = np.array(all_lyrics_embeddings_x)
    all_midi_emb_x = np.array(all_midi_emb_x)
    all_lyrics_W_midi_embeddings_x = np.array(all_lyrics_W_midi_embeddings_x)
    all_lyrics_labels_y = np.array(all_lyrics_labels_y)
                                      
    return all_lyrics_embeddings_x, all_midi_emb_x, all_lyrics_W_midi_embeddings_x, all_lyrics_labels_y

# %%
train_x_lyrics, train_x_midi, train_x_lyrics_w_midi, train_y = prepeare_embs_for_keras(train_lyrics_embeddings, train_lyrics_tokens, midi_embs_train.values())
val_x_lyrics, val_x_midi, val_x_lyrics_w_midi, val_y = prepeare_embs_for_keras(val_lyrics_embeddings, val_lyrics_tokens, midi_embs_val.values() )
# Out:
# 530it [00:13, 38.09it/s]
# 59it [00:12,  4.91it/s]

# %% [markdown]
# ### Build + Train LSTM Model
# late_cat param control the architecture to test.

# %%
late_cat = True # the Architecture where the concatenate of the midi vectors happens ***after*** the LSTM output
# late_cat = False # the Architecture where the concatenate of the midi vectors happens ***before*** the LSTM output

# %%
import tensorflow as tf
import keras
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM, Input, Bidirectional
from keras import Input
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.metrics import categorical_accuracy
from keras.layers import Concatenate
from tensorflow.keras import regularizers

# %%
l2_reg = regularizers.l2(1e-5)
midi_emb_dim = 25
hidden_units = 100
hidden_dim = 100
dropout_ratio = 0.4


def build_model_with_midi_late_cat(midi_emb_dim, lyric_shape):
    lyric_lstm = Sequential()
    lyric_lstm.add(Input(shape = lyric_shape))
    
#     lyric_lstm.add(LSTM(hidden_units, activation="relu"))
    lyric_lstm.add(LSTM(hidden_units, activation="relu", kernel_regularizer=l2_reg))
    
    decoder = Sequential()
    decoder.add(Input(shape = hidden_units + midi_emb_dim))
    decoder.add(Dropout(dropout_ratio))
    
#     decoder.add(Dense(hidden_dim))
    decoder.add(Dense(hidden_dim, kernel_regularizer=l2_reg))
    
    decoder.add(Dropout(dropout_ratio))
    
#     decoder.add(Dense(vocab_size))
    decoder.add(Dense(vocab_size, kernel_regularizer=l2_reg))
    
    decoder.add(Activation('softmax'))
    
    lyrics_input = Input(lyric_shape)
    midi_input = Input(midi_emb_dim)
    
    lyrics_emb = lyric_lstm(lyrics_input)    
    lyric_and_midi = Concatenate()([lyrics_emb, midi_input])
    words_prob = decoder(lyric_and_midi)
    model = Model(inputs=[lyrics_input, midi_input], outputs=words_prob)
    print(model.summary())
    return model


def build_model_with_midi_early_cat(lyric_shape):
    lyric_lstm = Sequential()
    lyric_lstm.add(Input(shape = lyric_shape))
    
#     lyric_lstm.add(LSTM(hidden_units, activation="relu"))
    lyric_lstm.add(LSTM(hidden_units, activation="relu", kernel_regularizer=l2_reg))
    
    lyric_lstm.add(Dropout(0.6))
    
#     lyric_lstm.add(Dense(vocab_size))
    lyric_lstm.add(Dense(vocab_size, kernel_regularizer=l2_reg))
    
    lyric_lstm.add(Activation('softmax'))
    
    
    lyrics_w_midi_input = Input(lyric_shape)
    words_prob = lyric_lstm(lyrics_w_midi_input)
    model = Model(inputs=lyrics_w_midi_input, outputs=words_prob)
    print(model.summary())
    return model

# %%
if late_cat:
    lyric_shape = (seq_len, w2v_dim)
    model = build_model_with_midi_late_cat(midi_emb_dim, lyric_shape)
    expr = 'late_cat'
else:
    lyric_shape = (seq_len, w2v_dim + midi_emb_dim)
    model = build_model_with_midi_early_cat(lyric_shape)
    expr = 'early_cat'

logdir = f'./{expr}_{datetime.now().strftime("%Y%m%d-%H%M%S")}'
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

callbacks=[EarlyStopping(patience=2, monitor='val_loss', mode='min'), tensorboard_callback]
opt = keras.optimizers.Adam()
# compile model
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=[categorical_accuracy])
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 10, 301)]    0
# __________________________________________________________________________________________________
# sequential (Sequential)         (None, 100)          160800      input_3[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 25)]         0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 125)          0           sequential[1][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# sequential_1 (Sequential)       (None, 7306)         750506      concatenate[0][0]
# ==================================================================================================
# Total params: 911,306
# Trainable params: 911,306
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# fit model
# , callbacks=[tensorboard_callback]
if late_cat:
    model.fit(x=[train_x_lyrics, train_x_midi], y=train_y, validation_data=([val_x_lyrics, val_x_midi], val_y), batch_size=128, epochs=10, callbacks=[tensorboard_callback])
else:
    model.fit(x=train_x_lyrics_w_midi, y=train_y, validation_data=(val_x_lyrics_w_midi, val_y), batch_size=128, epochs=10, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/10
#    2/1275 [..............................] - ETA: 2:19 - loss: 32.7374 - categorical_accuracy: 0.0000e+00WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.101423). Check your callbacks.
# 1275/1275 [==============================] - 39s 30ms/step - loss: 6.8284 - categorical_accuracy: 0.1197 - val_loss: 5.5893 - val_categorical_accuracy: 0.1673
# Epoch 2/10
# 1275/1275 [==============================] - 20s 16ms/step - loss: 5.3473 - categorical_accuracy: 0.1694 - val_loss: 5.4539 - val_categorical_accuracy: 0.1754
# Epoch 3/10
# 1275/1275 [==============================] - 24s 19ms/step - loss: 5.1414 - categorical_accuracy: 0.1826 - val_loss: 5.3315 - val_categorical_accuracy: 0.1857
# Epoch 4/10
# 1275/1275 [==============================] - 42s 33ms/step - loss: 5.0221 - categorical_accuracy: 0.1915 - val_loss: 5.2499 - val_categorical_accuracy: 0.1937
# Epoch 5/10
# 1275/1275 [==============================] - 24s 19ms/step - loss: 4.9334 - categorical_accuracy: 0.1970 - val_loss: 5.2401 - val_categorical_accuracy: 0.1916
# Epoch 6/10
# 1275/1275 [==============================] - 21s 16ms/step - loss: 4.8642 - categorical_accuracy: 0.2027 - val_loss: 5.2285 - val_categorical_accuracy: 0.1969
# Epoch 7/10
# 1275/1275 [==============================] - 24s 19ms/step - loss: 4.8134 - categorical_accuracy: 0.2075 - val_loss: 5.2303 - val_categorical_accuracy: 0.1956
# Epoch 8/10
# 1275/1275 [==============================] - 25s 20ms/step - loss: 4.7677 - categorical_accuracy: 0.2112 - val_loss: 5.2627 - val_categorical_accuracy: 0.1965
# Epoch 9/10
# 1275/1275 [==============================] - 25s 19ms/step - loss: 4.7267 - categorical_accuracy: 0.2169 - val_loss: 5.2419 - val_categorical_accuracy: 0.1978
# Epoch 10/10
# 1275/1275 [==============================] - 20s 16ms/step - loss: 4.6916 - categorical_accuracy: 0.2203 - val_loss: 5.2778 - val_categorical_accuracy: 0.2023

# %% [markdown]
# ## Generate Songs Lyrics

# %%
def sample(train_vocab_reversed, preds, wv, pad_vec):
    """
    Sample 1 word given the predictions
    """
#     helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds)
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
#     probas = np.random.multinomial(1, preds, 1)
#     print(np.max(probas))
#     next_idx = np.argmax(probas)
    next_idx = np.random.choice(len(preds), size=1, p=preds)[0]
    next_word = train_vocab_reversed[next_idx]
    if next_word in wv.vocab:
        next_word_vector = wv.vectors[wv.index2word.index(next_word)]
    else:
        next_word_vector = pad_vec
    return next_word, next_word_vector

def generate_song(midi_embs, sentences_number, seed_word, late_cat):

    # w2v_dim = 301
    # step = 1
    # seq_len = 5
    # vocab_size = len(train_vocab)
    train_vocab_reversed = {v:k for k,v in train_vocab.items()}

    generated = ''
    
    if late_cat:
        pad_vec = np.array([0] * (300 + 1))
    else:
        pad_vec = np.array([0] * (300 + 1 + midi_emb_dim))
            
    embeddings_context = []
    for i in range(seq_len-1):
        embeddings_context.append(pad_vec)
    word_emb = wv.vectors[wv.index2word.index(seed_word)]
    pad_vec = np.array([0] * (300 + 1))
    
    if late_cat:
        embeddings_context.append(word_emb)
    else:
        word_emb = np.concatenate([word_emb, midi_embs[0]])
        embeddings_context.append(word_emb)
        
    embeddings_context = np.array(embeddings_context)
    embeddings_context = np.expand_dims(embeddings_context, 0)

    generated = seed_word

    #Generate the text
    sentence_idx = 0
    while sentence_idx + 1 < sentences_number:
        #calculate next word
        preds = model.predict([embeddings_context, np.expand_dims(np.zeros(midi_emb_dim), 0)], verbose=0)[0]
        next_word, next_word_vec = sample(train_vocab_reversed, preds, wv, pad_vec)

        #add the next word to the text
        generated += " " + next_word
        if next_word == '&':
            generated += '\n'
            sentence_idx += 1

        # shift the sentence by one, and and the next word at its end
        embeddings_context = np.roll(embeddings_context, axis=1, shift=-1)
        
        if not late_cat:
            next_word_vec = np.concatenate([next_word_vec, midi_embs[sentence_idx]])
            
        embeddings_context[0, -1] = next_word_vec

    #print the whole text
    print(generated)

# %%
test_songs_midi_embeddings = list(all_midi_embs_test.values())
sentences_number_list = [len(song) for song in test_songs_midi_embeddings]
seed_words = ['close', 'if', 'dear', 'hiya', 'all']
# print(seed_words)
for midi_embs, sentences_number, seed_word in zip(test_songs_midi_embeddings, sentences_number_list, seed_words):
    print('Song Lyrics:\n')
    generate_song(midi_embs, sentences_number, seed_word, late_cat)
    print('\n\n')
# Out:
# Song Lyrics:
#
# close like they &
#  leave the rats back in away wo &
#  slavery the lawyers attend zone and i adown blackbird to long more &
#  ooh ce midnight jag soir &
#  roof hurting sister yo hey &
#  severed the this lot a love &
#  man you went back inside &
#  hang off on &
#  someday i snuggled a cassette shit &
#  oh i blue &
#  superfly ruined that morning &
#  broke double street as soft but something &
#  car and say ever good more &
#  baby i miss you &
#  there i changed blind &
#  it drank they to watch my aha &
#  you never gon na be tiny goodbye &
#  oh time of the chop &
#  everyone have on &
#  when they lost my bones pregnant we done can had to spin into and morning while your eye &
#  say you pull me crazy &
#  you any son it killing motherfucker auf and slashin &
#  feelin was have to hei &
#  lawabiding lido out is a pox tiffanytwisted &
#  santa says you could get to diggy do up back to always to my um &
#  so he gon na be my breaking behind one night of her basement &
#  and i need all it will hide &
#  you ai all place the the everything do tears keeps &
#  but i continue see you truly &
#  you cross you lonely &
#
#
#
#
# Song Lyrics:
#
# if the hawk khan the choke like to talk &
#  chorus darlin &
#  girl you will make your fantasy &
#  come with you i will really that i want to listen &
#  your love will show i deep &
#  your only i want for you &
#  and i do worry what is my soul &
#  oh myself go to messin his life that that all will made ahead &
#  it die to hook on &
#  i gon na suck a to all your fantasy of you breathe &
#  come out back now you face &
#  how say you wo you know &
#  what i got to work that alright &
#  i did get fall &
#  no one they really mean &
#  than and a truth with the doubt some kings &
#  i ask my gaze through lately with him around with your addicted and if we benz to miss happy &
#  and i went we i never running on around &
#  as i ai would blind to felt funky &
#  it in the danger &
#  so quite hurry take this pain baby toe that on everybody &
#  &
#  everybody else i so you face out in the dispute of to down &
#  dee no peeps the walkman door like that my place &
#  of the news &
#  who a pen &
#  the felt that need nothing what it loud by hold &
#  i kitchen his eyes linger &
#  you can barely it around &
#  your eyes around us a candlelight for a dizzy the shade in lola &
#  smokin from the letter buys of sha bailamos i beast &
#  i just heading boogie plight &
#  but i i wait heavymetal front a bar earth or &
#  dear the monkey lineman &
#  i make shadows and down &
#  hoo over a hoo &
#  whoa hey &
#  little dumb im woah &
#  a carson another joint spell &
#  come broken this someday today away he gon na stop in blue rain &
#
#
#
#
# Song Lyrics:
#
# dear i got or up a mountain stick &
#  for voices and so chuckie in killers &
#  they hate man sat young instead sniff ah ya hug &
#  better on stick the enemy late through around &
#  hard to change for worst now &
#  tomorrow like me wrong &
#  but just mess for you sweet in your direction &
#  there the troubles all how to chacha &
#  she was free me on my name &
#  like i special loved show you why &
#  follow yourself like it &
#  make it other baby &
#  come down with all your broken &
#  it hard to give to your lovin &
#  kisses my scent conmigo and lu kinky while the potion &
#  &
#  &
#  nodded nanana i moffats and delight &
#  in into abused has true it before &
#  is some thing these be your decency &
#  just give to dirty too &
#  and i know what why should fade &
#  you may be strong &
#  kiss me body i so damn &
#  &
#  welcome in the rain &
#  when you give me like you &
#  to you until you ever want to leave you &
#  dear &
#  they am you youyou &
#  just a sister the old of name &
#  but the place loves is of love &
#  the man in the hometown &
#  up my eyes scarlet we saw &
#  shoot i try down &
#  we wait made my socks that badness in earth &
#  lido stand crying &
#  from a distance all us by &
#  you saw on our eyes and nile &
#  some tonight up up and try &
#
#
#
#
# Song Lyrics:
#
# hiya tell me i want to want to on to too all &
#  i need a lantern &
#  i live that illusion young tell it here and you not after &
#  i like your manic friend &
#  that in to roll &
#  there ai this way we can hold everybody scene &
#  leave the sappy rio experiencia &
#  sing suppper overwhelming man sure you fly &
#  believin i is on a song &
#  if riding read claim rags and the candle counter &
#  i changed loosen and a jede plus mic us &
#  that number day by your emotions me people strong &
#  i can find your life these time time &
#  i seen now &
#  you been le end &
#  bring you full paradise dreams dark as &
#  dreaming to continues &
#  was the piercing store you still hardearned oh any more hand &
#  you said how do i remember it no girl &
#  before thing little are you could told &
#  i better home &
#  i see a dude worse and and i begotten pain dreads &
#  &
#  bleed cupid through but yeah &
#  things you got betta and will so still &
#  all that door as a everbody is &
#  tired &
#  you the good deep &
#  then your love is people by &
#  to see there knew i baby is no doubt &
#  for everyone i turn just &
#  you spinning &
#  sighs right &
#  squeeze gas the starry winter &
#  they grieve a key &
#  thumpity more than fun &
#  just all us time you be down away in me that black in truth &
#  i between the park the studio he class sailed and let at burning &
#
#
#
#
# Song Lyrics:
#
# all just i holding bright at &
#  and maybe but and there not could sudden &
#  you made for from mary &
#  i could change bebopalula just free there baby &
#  then made my natural man &
#  zoot suit riot &
#  riot &
#  music his consideration &
#  though shallow after the side &
#  we have preach i was another empty lives &
#  if you been afraid your pride &
#  i live my heart i am &
#  someday you was true &
#  like that it gon na went put &
#  gon na do keep that cosa or stool for you on a words we &
#  i furious the heals bag just strange &
#  naughtynaughty just gon na ab tails rags parties ahhahaha &
#  livin downers &
#  no words to go and you bouncebouncin &
#  games of canvas &
#  young cuts in the kinky direction &
#  sell your box faces and this christmas norman &
#  i never borrow to find the crack &
#  you belong it you need me goodbye now &
#  gon na think i love you &
#  &
#  but where done can you do here when i shock at the crowd and rising &
#  capone had you half magic &

# %%
test_songs_midi_embeddings = list(all_midi_embs_test.values())
sentences_number_list = [len(song) for song in test_songs_midi_embeddings]
seed_words = ['love', 'love', 'love', 'love', 'love']
# print(seed_words)
for midi_embs, sentences_number, seed_word in zip(test_songs_midi_embeddings, sentences_number_list, seed_words):
    print('Song Lyrics:\n')
    generate_song(midi_embs, sentences_number, seed_word, late_cat)
    print('\n\n')
# Out:
# Song Lyrics:
#
# love were undesirable &
#  so soulful motherfuckers &
#  with it back on here &
#  when there disappointments again &
#  i think something so way &
#  my small she still done me yeah &
#  whenever you got a part &
#  a boy as the workin is hoodlums &
#  being the street under to mistake teasing balls &
#  and and baby if she rap anothin come &
#  she knows i racing they salvation key &
#  how we is feed to without door through &
#  now someone shining up the jaw &
#  but you ca answer and by her yet &
#  i die in they incense &
#  in your kiss &
#  so a things ooh i think i gon na na na na na na na na na na na na na na na na na na na na na oh &
#  and bring me to love i call &
#  sweet home leave me out &
#  your load can the night stand forever &
#  darling sure got believing nigga &
#  sitting of hell deep sign to totaled complain mony five hand china with all passion &
#  of not iesha and arrow the retrace and now and fate &
#  since are so forget you guide it them everywhere like she and happy &
#  she standing here huh now &
#  after to the side her earth &
#  when our son and tired &
#  happy eyes to eyes blackstreet &
#  i it love you &
#  here yes the reason tonight &
#
#
#
#
# Song Lyrics:
#
# love is that blue before she cried &
#  and but could you work me on my bed from stupid emotions &
#  i feels &
#  i letting me &
#  and so like what just &
#  to leave your gold so no one &
#  so in kennt tells them one time &
#  we going comes on in the midst space &
#  hey hey and grow with your knees away &
#  and i start grieve &
#  i just must your figure be my place to play &
#  i saw to dance my scene but giant hold &
#  oh one my hands &
#  kiss you &
#  i stumble and it close in clearly &
#  cut your reason through &
#  just a rumor for whisperin from bitches &
#  within the dub gone &
#  melody a retreat &
#  way fire and and never really want to stay &
#  and it watching the time that i gave &
#  weather i kissed i gon na make a song &
#  the shamari &
#  sheet out to slim flow texas this fun nigga disappear for soir i ca stop &
#  no my search is pissed i &
#  inside each other &
#  that sleep pills pina &
#  cause i holding a brand &
#  and i gon na get not clean when two &
#  can carry big &
#  conventionality fabulous bucket the we what your after to leavin i happy me &
#  i saw it fuckin that canopy &
#  what you were or an everything &
#  as i cried now on time turning &
#  straight words feats &
#  she knew away &
#  my got will make my mind wo know to understand &
#  i wo get have fine &
#  be it tearing now you saying my heart &
#  i can tomorrow else &
#
#
#
#
# Song Lyrics:
#
# love made the drinking why i fair &
#  of not starts anything &
#  i feel &
#  when you got if &
#  do me want you a man of slim out through my life &
#  and my minds how can you saw &
#  but never could never do &
#  gim do you like our rest &
#  i see the mornin brown ai a foe &
#  this day anything you will stay from i &
#  take you is me &
#  you is hard to be strong &
#  why you big money yard &
#  come that funny is only break tables why &
#  &
#  just think you will see &
#  buggin oldfashioned down &
#  or we a problem so talk quite delaying &
#  cause when it ends into i glee &
#  who &
#  i pocket it to love you the booty &
#  i takes baby made you tell the lights &
#  that tell when you ai boom with what you should you nigga like the fuck why me i jean &
#  you know it my majestic &
#  and when then always you do it &
#  you listen me on the block i think through here &
#  got with this heartbreaker sombra three fucking frightening through by this &
#  had times of camino well running and evilness returned shall between &
#  spread that feint your life garden go on a shimmering i you do guess &
#  up the tape i like these house twelve getting keepin safe &
#  &
#  and that dub careless &
#  and far nobody ai te stop soon &
#  i had two fired of without &
#  someday no malts &
#  stay through a daughter hopes from the rhyme &
#  copa deity zoot rendezvous lowly macht &
#  there found a time to enter &
#  he saw from the freaky white &
#  why it old set me tiffanytwisted &
#
#
#
#
# Song Lyrics:
#
# love go out &
#  please could &
#  but athinking bull reassure &
#  hey in in night re &
#  come on away the one true &
#  &
#  it bad out of me &
#  tell some a way i need &
#  your i wear that cripin to love &
#  i think she straight around in &
#  if i saw a sound to when our white dog and rocking &
#  laugh when she see his rap doll &
#  i happy to responded only honies leavin song &
#  look days i laughing &
#  and and what dre was born what &
#  meditation better wind &
#  facts &
#  arms your hands and things they left you &
#  to respect it taking it no life it will see &
#  you listen to the obsession me &
#  all the first of sundoobiest anymore &
#  and a one tormento jealous for a one far black more &
#  if i i both from sixpack that yard &
#  intentions they drink the artis &
#  what we going what ok do something tryin to quit oh you my queen on rescue &
#  i how you thinking i would avoid &
#  a woman land kids all that someone loved be me &
#  if i in those lody and i lose my ass apparel &
#  he sat crashed lies &
#  stinkin that with a mid0s like the cat at her brings &
#  always playing i both no word &
#  i made to until the own day lucky &
#  i know so we is liked nobody i do it doing to be honey &
#  and made me fighting out down above &
#  i moss away to meet away subsides &
#  until his bombs steed &
#  much and waiter and ginger &
#  and making what i changed in before &
#
#
#
#
# Song Lyrics:
#
# love is long you do to had you free &
#  and it talkin here i feel all is free &
#  oh games am love is every years tonight &
#  i am two for you my mind of go &
#  i miss a way i still got a lot &
#  when every sun except attitude &
#  take you me respect me like it all so warm &
#  but they both feelings to do him something &
#  ai for why the waterloo game of heart &
#  shit when where from tickin they they drown hill your like &
#  fishin bring &
#  hours for nichts and my glass splits on &
#  born anticipating caucasians &
#  she dreaming at my tears &
#  &
#  darlin guitar so i big is &
#  bebopalula when then yellin flowin and it corpse her eyes &
#  in your fantasy &
#  no things that say he quickly all &
#  but you colors a world happened when i right &
#  but you stop they can see &
#  how the time in the answers &
#  if how talk &
#  see where you walk &
#  out oh ready him on her heart &
#  and i really nothing with the chart &
#  there can you steal her eyes we sick shine &
#  someday that archie &

# %%
test_songs_midi_embeddings = list(all_midi_embs_test.values())
sentences_number_list = [len(song) for song in test_songs_midi_embeddings]
seed_words = ['baby', 'baby', 'baby', 'baby', 'baby']
# print(seed_words)
for midi_embs, sentences_number, seed_word in zip(test_songs_midi_embeddings, sentences_number_list, seed_words):
    print('Song Lyrics:\n')
    generate_song(midi_embs, sentences_number, seed_word, late_cat)
    print('\n\n')
# Out:
# Song Lyrics:
#
# baby love pressed that leave this weeks to hide &
#  tomorrow is a stuff to &
#  i see your side yes and me i just like your empty time &
#  i should gon na be rose &
#  we took &
#  it there these use it hell for &
#  i month in my soul &
#  you foe makin on my mouth &
#  you tell me the diggity sound &
#  and look is a funeral &
#  that just not comes &
#  but when i joke &
#  the propers song &
#  enough it your rent back two problem &
#  i lose but time to need her girl your song is you breeze the yearning with your eyes for her &
#  it as the shadows to a song there &
#  ey twistin in swords anymore her eat with us &
#  kiss it into the balls that paintings are further &
#  and got through i jiggy to seem at our brain &
#  i sorry i like my diamonds of the basis &
#  and he nothing mean a canopy i knocks to pass run you &
#  after i in this right &
#  such you it a cough &
#  &
#  i go here sign to the past &
#  and not you see the shit another fuck and breakers &
#  my ticket who crews it said to love somebody &
#  to it the climb around no his any bad &
#  in my competitive lets &
#  love your little needs &
#
#
#
#
# Song Lyrics:
#
# baby you need you in grind &
#  over which man like a leaf got a laser &
#  on the hotel over &
#  lookin anyway of your eyes lenya with me just still love door &
#  and tell me whatever &
#  i can worry i &
#  walk after the sailor bail &
#  nothing since while me where he always a to sang &
#  cant i gon na stop &
#  no one again &
#  that love stan my hand &
#  bad low middle the dream &
#  in my eye sight &
#  not give for i so a woman &
#  and you hear you hope you apart &
#  i all bouncin to run to i care &
#  nothin spent the places of my charms &
#  when you refuse inside but on then &
#  i everything home &
#  and bring or two heute &
#  how was blurt help &
#  my diploma take your wings &
#  smilin in my eyes and let without &
#  rock yourself so so easy and i know no i can feel &
#  oh i can know you can is it blue deep &
#  christmas i everything them &
#  &
#  that turns to be callin &
#  me to me it hour way or baby &
#  so just meant you work the music &
#  with me pass you tell me what i tell &
#  now i can look you i know you awalking one of whole big part &
#  ah where so seem &
#  grand yellin i had &
#  far &
#  i stare out the front why &
#  i all my fantasy &
#  &
#  then back out in the middle &
#  they say and she see sure &
#
#
#
#
# Song Lyrics:
#
# baby it bound on i always think my mundane &
#  but i rappin stand on with my window &
#  you walk at your beat &
#  check go down &
#  now you a tipped &
#  &
#  it it drank like a chaperon to number &
#  since they ai daly an sidewalk down and in the doggie &
#  respect need the wounds vacation respectfully &
#  absolutely i wo yes in the egyptian should &
#  well so wrap on bathrobe be get different &
#  see me on whose master of the babe &
#  i said i changed attack with a place &
#  i think that that &
#  it right we would &
#  hit and you anybody every gas &
#  we sees of the beautiful time &
#  more in the pieces &
#  the end for right &
#  givin on will everybody a great naughtynaughty damn of shades &
#  look and keep and so violence &
#  any missing crying no keys we got a prince &
#  down with a following my attitude baby &
#  in my bell ohwoho songs &
#  and but we say i say to be i superman &
#  i stop is for &
#  sitting my life so &
#  observe inside beside like of &
#  pleased loved &
#  that i am right in my nuevo &
#  i dry knew for that he win can on &
#  i knew your lizards through your destiny &
#  wonder you you without it &
#  and the light is fill you to buy &
#  a belief to so drunk so are beats high &
#  every nice pack long love all takes &
#  but when the way there like i brought there &
#  gentle but or whip and you for my woman &
#  take the head and history her jam &
#  meet they that chopped buck &
#
#
#
#
# Song Lyrics:
#
# baby can i make you feel chaka &
#  let me superman for you &
#  da get tragic but to change or bitin &
#  turn a young clothes went &
#  could i make you got crying with like i despise &
#  take you &
#  with me for this will it &
#  but because nothing &
#  lido ah and if you been so mean &
#  just in the poison as a mind on my greatest &
#  your name just whoawhoawhoawhoa &
#  a oohoohoooooo tonight in a guy from your biggest &
#  there the picture can i sure it going &
#  i gone &
#  i need you built &
#  just on the truth to be you with &
#  out on the action i down with you home together &
#  it hard to dance around &
#  day you are the end &
#  take my secret you feel around &
#  baby put somethin off to me &
#  fall outta had than individuals wrong &
#  love might got of fantasy girl &
#  can you be a kingdom oh the world to find &
#  you may still &
#  i fought the papers &
#  you used me ascapped about too so it &
#  let me start think tomorrow girl &
#  i lie &
#  &
#  i can do it tonight &
#  i want me over around &
#  baby you never feel me &
#  i had within gray &
#  and i goin the park always tickin &
#  open that fact are take moments the shadows &
#  just back forever before you turn a chance &
#  she that like die &
#
#
#
#
# Song Lyrics:
#
# baby and you yourself &
#  you do believe about the time &
#  you you want to sit for together i can get like all he given &
#  shit &
#  to knees so moans and will look ai hairy and it just no hungry &
#  i gon na hear my energy marathon &
#  hmmm &
#  never may carry to love you &
#  man teeth she been believes and i hear the jam &
#  i need a light everywhere your body give me to feel it &
#  just the rhythm of the this world baby &
#  it goes &
#  i can know it a should &
#  ooh go in fed tonight &
#  now for your coast &
#  it a hope there alone made her star with massachusetts and but &
#  all the sun millennium beside the unkind &
#  laugh broke that can touch fifty &
#  while on the emptiness waiting at woah &
#  looking woooooo miles goretex real open a rat eyes &
#  i do have to be there &
#  why it i has a tragedy &
#  we spent from an preys too &
#  a sign i telling to you you takes my heart in the shores &
#  i can get through my sights &
#  goes &
#  around these days &
#  up in me for me &

# %%
test_songs_midi_embeddings = list(all_midi_embs_test.values())
sentences_number_list = [len(song) for song in test_songs_midi_embeddings]
seed_words = ['god', 'god', 'god', 'god', 'god']
# print(seed_words)
for midi_embs, sentences_number, seed_word in zip(test_songs_midi_embeddings, sentences_number_list, seed_words):
    print('Song Lyrics:\n')
    generate_song(midi_embs, sentences_number, seed_word, late_cat)
    print('\n\n')
# Out:
# Song Lyrics:
#
# god the way &
#  yeah and it tries to seem &
#  oh kiss in my eyes &
#  girl tell me what i gon na be &
#  &
#  not said you never go &
#  &
#  i got around where they going by &
#  what you told &
#  really hard to lean again &
#  someday i help her &
#  now why ai sorry &
#  i through her shines but things mistaken &
#  once &
#  i wo to like a breeze together in all king close &
#  idiots slam away &
#  recognize you wo feed &
#  i kill to do you &
#  you know they will just for my pretty crying &
#  i know as the same bandits so what have i wastin now &
#  the season lung book &
#  i sang a time you four secrets &
#  was a jimi flow there you darlin &
#  we make a bridge of what &
#  no did suspect when we diggity on the street &
#  west bump gon na rap love attracted &
#  and nothing big hot dick wish &
#  and the pennsylvania takes up me closes &
#  put the rhythm to the president burns everybody &
#  no good not to conscience rocking &
#
#
#
#
# Song Lyrics:
#
# god me all my friends &
#  and &
#  ooh do you climb ever not &
#  but yourself got but turning &
#  in the rhythm &
#  leap bath i very much my boy &
#  and that you know why you say &
#  but all the world someone awake &
#  all everybody way just has how brand catch and rock &
#  at you everybody child the guy ones any drowning then ooh and you feel what no good throwaway &
#  she got my breath nights &
#  sailing bye yeah benz &
#  funny diary me and we ca have it &
#  in a steadliy its everyday but the had being heads &
#  that and sure he true you to see &
#  i say or i a best time to learn &
#  then that we meet like hungry &
#  and sittin up in your uptown makes &
#  say up me the border &
#  hey across the two dreams &
#  wan na oh &
#  no thing was the king &
#  she got ta old life cute the best groove &
#  everybody them bag before &
#  seek of broadway &
#  i do photograph and ca sailors &
#  yes &
#  that that reads biggest look man large shit into in and rocks till &
#  jimmy got ta duke &
#  and rosanna teasing outer has filling for twelve &
#  puzzle swirling days meter my love &
#  there got the floor it bills bitin that got too &
#  she ruined he mean it home &
#  and i bad swingers &
#  and they it headed when they zoot somehow &
#  oh no have beat my balls with the smoke ego &
#  i there a loneliness &
#  because instinctively was wrong &
#  i ca do so your brightest daylight &
#  then your eyes door that it &
#
#
#
#
# Song Lyrics:
#
# god is a earl &
#  he tells that liberty loved man &
#  biz just let them know oh &
#  if the second middle but so said i did you was when so a barrel like paintings &
#  but i jimmy high ole asylum &
#  braille changed minutes bebopalula scream &
#  thanks here no fates so i heart you wanted me side &
#  were smell a pearls &
#  and whenever intergalactic things gettin are whoa &
#  eyed &
#  she me a new paradise &
#  when everybody was free being confused &
#  but reverently cheat to lullaby shit &
#  give this ring and i got a pavement light up &
#  a attention you safe &
#  an works right love believe they got &
#  or wonder you thinking do caught it for the breeze &
#  goodnight i all trippin on &
#  havin &
#  cause on a hit &
#  starry big similar craft bono &
#  drugs that tails painful nanny hose behind slowly &
#  i ohsofrail waitin a dog to fly &
#  sometimes different we given got of falling &
#  beware when an dodge saloon queen you girl magic &
#  i allowed see center an low world &
#  i ai nothin paint to be every magic or what is damn of time &
#  and the wicked cat ho momomony at the lord &
#  he of you all up from a cast oh my &
#  you tucked &
#  by &
#  and until that you get on and it in oldfashioned before &
#  i wish sense no night with my lips &
#  no you gettin moving a marry &
#  measure this race not cover oh so you niggas do bars morning pain &
#  rosy up through the late and not do cry &
#  then we think for time i stand with me &
#  and ooh ah by night &
#  rifle and pull out the memories &
#  that sorrow ai always &
#
#
#
#
# Song Lyrics:
#
# god there you do babe you say now &
#  it the night was on the erzhl &
#  something to it a new penny stone every livin yours &
#  death what boom a time saw &
#  oh you turn the summer graces &
#  the words i got a eyeet &
#  falling of body thousands the walkman &
#  always might do you need you &
#  chorus &
#  by corpse i nigh &
#  tails i rasta &
#  from nine pretty loneliness &
#  everything go to everything he sinner else going &
#  this do matter you do it &
#  look it my head &
#  thugging it of fool i need for the way &
#  all you sold my fire &
#  if all we go absolutely &
#  i do know you came and key they say goodbye &
#  i do know what to know &
#  look got still did reach &
#  i this hear i see &
#  no love you baby &
#  you can bring you now too she feeling &
#  ride up into my hands and system &
#  shut all down and at mammals &
#  got it on a brighter riding &
#  keep the microphone and heavy and stumblin dog &
#  every way your fantasy after orgy &
#  take me to you these same mellow babe &
#  i need to work that strong morning &
#  power in time over my lips &
#  oh suddenly darkness the boy just need too &
#  closer out &
#  and girls the joy in it &
#  drop a answered &
#  &
#  people finally view &
#
#
#
#
# Song Lyrics:
#
# god it church without the night &
#  talking that you can get my games &
#  &
#  things used to weaken &
#  you go to groovy can take a friend at me &
#  she can from like my floating the vida rocks in the endless &
#  in a cast motives &
#  do or dog and i askin a helping &
#  you fallen back a bunch man down off up bout on my body remains filled of with the pinch to in yourself &
#  but the ride comes until i knew it i always mine &
#  there is the break of the car &
#  knocking around sea there there got feel with slowly &
#  mary and i quickest say let &
#  when you could be &
#  you need my tiny doll &
#  and if you said do you clean in city me &
#  the drums and too ghost &
#  and newborn oh i cock grab low right &
#  everybody go ta got money it true &
#  i get faith &
#  in my life with a winter cup &
#  grandjust were afraid so gon na worry two &
#  coz yeah doll the fuck &
#  in a violence embrace in your south &
#  size planetary and i gon na dance &
#  ohoh &
#  no fever little sweet girl ai let it sure &
#  no you do said now you do listen the boy in 0 &
